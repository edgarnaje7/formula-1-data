# %% [markdown]
# ## Librerías

# %%
#Necesitamos esta paqueteria para la url
import requests
import json
#Llamamos a la API
url ='https://ergast.com/api/f1/2022/22/results.json'

# %%
# Se define como un requerimento
response = requests.get(url)

# %%
# .content para mostrarnos el contenido de response
response.content
# Out:
# b'{"MRData":{"xmlns":"http:\\/\\/ergast.com\\/mrd\\/1.5","series":"f1","url":"http://ergast.com/api/f1/2022/22/results.json","limit":"30","offset":"0","total":"20","RaceTable":{"season":"2022","round":"22","Races":[{"season":"2022","round":"22","url":"http:\\/\\/en.wikipedia.org\\/wiki\\/2022_Abu_Dhabi_Grand_Prix","raceName":"Abu Dhabi Grand Prix","Circuit":{"circuitId":"yas_marina","url":"http://en.wikipedia.org/wiki/Yas_Marina_Circuit","circuitName":"Yas Marina Circuit","Location":{"lat":"24.4672","long":"54.6031","locality":"Abu Dhabi","country":"UAE"}},"date":"2022-11-20","time":"13:00:00Z","Results":[{"number":"1","position":"1","positionText":"1","points":"25","Driver":{"driverId":"max_verstappen","permanentNumber":"33","code":"VER","url":"http:\\/\\/en.wikipedia.org\\/wiki\\/Max_Verstappen","givenName":"Max","familyName":"Verstappen","dateOfBirth":"1997-09-30","nationality":"Dutch"},"Constructor":{"constructorId":"red_bull","url":"http:\\/\\/en.wikipedia.org\\/wiki\\/Red_Bull_
# ...

# %%
#Lo transfromamos a json para que se vea mucho mas amigable
json.loads(response.content)
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2022/22/results.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '20',
#   'RaceTable': {'season': '2022',
#    'round': '22',
#    'Races': [{'season': '2022',
#      'round': '22',
#      'url': 'http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Grand_Prix',
#      'raceName': 'Abu Dhabi Grand Prix',
#      'Circuit': {'circuitId': 'yas_marina',
#       'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#       'circuitName': 'Yas Marina Circuit',
#       'Location': {'lat': '24.4672',
#        'long': '54.6031',
#        'locality': 'Abu Dhabi',
#        'country': 'UAE'}},
#      'date': '2022-11-20',
#      'time': '13:00:00Z',
#      'Results': [{'number': '1',
#        'position': '1',
#        'positionText': '1',
#        'points': '25',
#        'Driver': {'driverId': 'max_verstappen',
#         'permanentNumber': '33',
#         'code': 'VER',
# ...

# %%
# Guardamos esto en la variable content
content = json.loads(response.content)

# %%
#Asi mostramos que hay en todas esas especifciaciones
content['MRData']['RaceTable']['Races'][0]['Results']
# Out:
# [{'number': '1',
#   'position': '1',
#   'positionText': '1',
#   'points': '25',
#   'Driver': {'driverId': 'max_verstappen',
#    'permanentNumber': '33',
#    'code': 'VER',
#    'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#    'givenName': 'Max',
#    'familyName': 'Verstappen',
#    'dateOfBirth': '1997-09-30',
#    'nationality': 'Dutch'},
#   'Constructor': {'constructorId': 'red_bull',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#    'name': 'Red Bull',
#    'nationality': 'Austrian'},
#   'grid': '1',
#   'laps': '58',
#   'status': 'Finished',
#   'Time': {'millis': '5265914', 'time': '1:27:45.914'},
#   'FastestLap': {'rank': '6',
#    'lap': '54',
#    'Time': {'time': '1:29.392'},
#    'AverageSpeed': {'units': 'kph', 'speed': '212.676'}}},
#  {'number': '16',
#   'position': '2',
#   'positionText': '2',
#   'points': '18',
#   'Driver': {'driverId': 'leclerc',
#    'permanentNumber': '16',
#    'code': 'LEC',
# ...

# %%
# Funcion de pandas DataFrame para convertirlo a un Data FRame
import pandas as pd
pd.DataFrame(content['MRData']['RaceTable']['Races'][0]['Results'])
# Out:
#    number position positionText points  \
# 0       1        1            1     25
# 1      16        2            2     18
# 2      11        3            3     15
# 3      55        4            4     12
# 4      63        5            5     10
# 5       4        6            6      9
# 6      31        7            7      6
# 7      18        8            8      4
# 8       3        9            9      2
# 9       5       10           10      1
# 10     22       11           11      0
# 11     24       12           12      0
# 12     23       13           13      0
# 13     10       14           14      0
# 14     77       15           15      0
# 15     47       16           16      0
# 16     20       17           17      0
# 17     44       18           18      0
# 18      6       19           19      0
# 19     14       20            R      0
#
#                                                Driver  \
# 0   {'driverId': 'max_verstappen', 'permanentNumbe...
# ...

# %%
# Queremos obtener todos los resultados de las carreras del 2022. Esto se hara utilizando un for
for i in  list(range(1,23)):
    url ='https://ergast.com/api/f1/2022/{}/results.json'
    response = requests.get(url.format(i))
    content = json.loads(response.content)

# %% [markdown]
# ## Tabla de todas las carreras del 2022

# %%
# Hay que crear un data frame vacia y luego ir agregando los elementos que se van creando a nuestra lista
df_results_2022=pd.DataFrame()
# Ahora corremos otra vez nuestra for añadiendole a la lista los valores obtenidos
for i in  range(1,23):
    url ='https://ergast.com/api/f1/2022/{}/results.json'
    response = requests.get(url.format(i))
    content = json.loads(response.content)
    df_results_2022 = df_results_2022.append(content['MRData']['RaceTable']['Races'][0]['Results'])
# Out:
# C:\Users\danin\AppData\Local\Temp\ipykernel_2568\1465105594.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results_2022 = df_results_2022.append(content['MRData']['RaceTable']['Races'][0]['Results'])
# C:\Users\danin\AppData\Local\Temp\ipykernel_2568\1465105594.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results_2022 = df_results_2022.append(content['MRData']['RaceTable']['Races'][0]['Results'])
# C:\Users\danin\AppData\Local\Temp\ipykernel_2568\1465105594.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results_2022 = df_results_2022.append(content['MRData']['RaceTable']['Races'][0]['Results'])
# ...

# %%
df_results_2022
# Out:
#    number position positionText points  \
# 0      16        1            1     26
# 1      55        2            2     18
# 2      44        3            3     15
# 3      63        4            4     12
# 4      20        5            5     10
# ..    ...      ...          ...    ...
# 15     47       16           16      0
# 16     20       17           17      0
# 17     44       18           18      0
# 18      6       19           19      0
# 19     14       20            R      0
#
#                                                Driver  \
# 0   {'driverId': 'leclerc', 'permanentNumber': '16...
# 1   {'driverId': 'sainz', 'permanentNumber': '55',...
# 2   {'driverId': 'hamilton', 'permanentNumber': '4...
# 3   {'driverId': 'russell', 'permanentNumber': '63...
# 4   {'driverId': 'kevin_magnussen', 'permanentNumb...
# ..                                                ...
# 15  {'driverId': 'mick_schumacher', 'permanentNumb...
# ...

# %%
# APlicamos lambda para extraer el nombre del conductor del json y solo dejarlo justo, con el nombre del conductor
df_results_2022['Driver'] = df_results_2022['Driver'].apply(lambda x: x['driverId'])
df_results_2022
# Out:
#    number position positionText points           Driver  \
# 0      16        1            1     26          leclerc
# 1      55        2            2     18            sainz
# 2      44        3            3     15         hamilton
# 3      63        4            4     12          russell
# 4      20        5            5     10  kevin_magnussen
# ..    ...      ...          ...    ...              ...
# 15     47       16           16      0  mick_schumacher
# 16     20       17           17      0  kevin_magnussen
# 17     44       18           18      0         hamilton
# 18      6       19           19      0           latifi
# 19     14       20            R      0           alonso
#
#                                           Constructor grid laps  \
# 0   {'constructorId': 'ferrari', 'url': 'http://en...    1   57
# 1   {'constructorId': 'ferrari', 'url': 'http://en...    3   57
# 2   {'constructorId': 'mercedes', 'url': 'http://e...    5   57
# ...

# %%
# Aplicamos lamba de nuevo para convertir los puntos a valores numericos
df_results_2022['points'] = df_results_2022['points'].apply(lambda x: float(x))
df_results_2022.head()
# Out:
#   number position positionText  points           Driver  \
# 0     16        1            1    26.0          leclerc
# 1     55        2            2    18.0            sainz
# 2     44        3            3    15.0         hamilton
# 3     63        4            4    12.0          russell
# 4     20        5            5    10.0  kevin_magnussen
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'ferrari', 'url': 'http://en...    1   57  Finished
# 1  {'constructorId': 'ferrari', 'url': 'http://en...    3   57  Finished
# 2  {'constructorId': 'mercedes', 'url': 'http://e...    5   57  Finished
# 3  {'constructorId': 'mercedes', 'url': 'http://e...    9   57  Finished
# 4  {'constructorId': 'haas', 'url': 'http://en.wi...    7   57  Finished
#
#                                            Time  \
# 0  {'millis': '5853584', 'time': '1:37:33.584'}
# 1       {'millis': '5859182', 'time': '+5.598'}
# ...

# %%
# Ocupamos grouby con el parametro Driver para que se haga la suma de todos los corredores cada uno
df_results_2022.groupby(['Driver']).agg({'points':'sum'})
# Out:
#                  points
# Driver
# albon               4.0
# alonso             81.0
# bottas             47.0
# de_vries            2.0
# gasly              23.0
# hamilton          233.0
# hulkenberg          0.0
# kevin_magnussen    21.0
# latifi              2.0
# leclerc           291.0
# max_verstappen    433.0
# mick_schumacher    12.0
# norris            116.0
# ocon               89.0
# perez             291.0
# ricciardo          34.0
# russell           262.0
# sainz             228.0
# stroll             18.0
# tsunoda            12.0
# vettel             37.0
# zhou                6.0

# %%
# Ocupamos sort by para acomodar nuestros datos
df_results_2022.groupby(['Driver']).agg({'points':'sum'}).sort_values
# Out:
# <bound method DataFrame.sort_values of                  points
# Driver
# albon               4.0
# alonso             81.0
# bottas             47.0
# de_vries            2.0
# gasly              23.0
# hamilton          233.0
# hulkenberg          0.0
# kevin_magnussen    21.0
# latifi              2.0
# leclerc           291.0
# max_verstappen    433.0
# mick_schumacher    12.0
# norris            116.0
# ocon               89.0
# perez             291.0
# ricciardo          34.0
# russell           262.0
# sainz             228.0
# stroll             18.0
# tsunoda            12.0
# vettel             37.0
# zhou                6.0>

# %%
# Ascending = false para acomodarlos de manera no ascendente
df_results_2022.groupby(['Driver']).agg({'points':'sum'}).sort_values( by = 'points', ascending = False)
# Out:
#                  points
# Driver
# max_verstappen    433.0
# perez             291.0
# leclerc           291.0
# russell           262.0
# hamilton          233.0
# sainz             228.0
# norris            116.0
# ocon               89.0
# alonso             81.0
# bottas             47.0
# vettel             37.0
# ricciardo          34.0
# gasly              23.0
# kevin_magnussen    21.0
# stroll             18.0
# tsunoda            12.0
# mick_schumacher    12.0
# zhou                6.0
# albon               4.0
# latifi              2.0
# de_vries            2.0
# hulkenberg          0.0

# %%
# Ahora hagampos lo mismo pero para Constructor
# APlicamos lambda para extraer el nombre del conductor del json y solo dejarlo justo, con el nombre del conductor
df_results_2022['Constructor'] = df_results_2022['Constructor'].apply(lambda x: x['constructorId'])
df_results_2022
# Out:
#    number position positionText  points           Driver Constructor grid  \
# 0      16        1            1    26.0          leclerc     ferrari    1
# 1      55        2            2    18.0            sainz     ferrari    3
# 2      44        3            3    15.0         hamilton    mercedes    5
# 3      63        4            4    12.0          russell    mercedes    9
# 4      20        5            5    10.0  kevin_magnussen        haas    7
# ..    ...      ...          ...     ...              ...         ...  ...
# 15     47       16           16     0.0  mick_schumacher        haas   12
# 16     20       17           17     0.0  kevin_magnussen        haas   16
# 17     44       18           18     0.0         hamilton    mercedes    5
# 18      6       19           19     0.0           latifi    williams   20
# 19     14       20            R     0.0           alonso      alpine   10
#
#    laps            status                                          Time  \
# ...

# %%
df_results_2022.groupby(['Constructor']).agg({'points':'sum'}).sort_values( by = 'points', ascending = False)
# Out:
#               points
# Constructor
# red_bull       724.0
# ferrari        519.0
# mercedes       495.0
# alpine         170.0
# mclaren        150.0
# aston_martin    55.0
# alfa            53.0
# alphatauri      35.0
# haas            33.0
# williams         8.0

# %% [markdown]
# ## Tabla de Races

# %%
content['MRData']['RaceTable']['Races']
# Out:
# [{'season': '2022',
#   'round': '22',
#   'url': 'http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Grand_Prix',
#   'raceName': 'Abu Dhabi Grand Prix',
#   'Circuit': {'circuitId': 'yas_marina',
#    'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#    'circuitName': 'Yas Marina Circuit',
#    'Location': {'lat': '24.4672',
#     'long': '54.6031',
#     'locality': 'Abu Dhabi',
#     'country': 'UAE'}},
#   'date': '2022-11-20',
#   'time': '13:00:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '25',
#     'Driver': {'driverId': 'max_verstappen',
#      'permanentNumber': '33',
#      'code': 'VER',
#      'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#      'givenName': 'Max',
#      'familyName': 'Verstappen',
#      'dateOfBirth': '1997-09-30',
#      'nationality': 'Dutch'},
#     'Constructor': {'constructorId': 'red_bull',
#      'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
# ...

# %%
# Crearemos ahora una , con la informacion de las carreras
# Creamos un diccionario
races = {'season': [],
        'round': [],
        'raceName': [],
        'circuitId': [],
        'lat': [],
        'long': [],
        'country': [],
        'date': [],
        'url': [],}

# %%
for i in list(range(2010,2023)):
    url ='https://ergast.com/api/f1/{}.json'
    response = requests.get(url.format(i))
    content = json.loads(response.content)
    
    for item in content['MRData']['RaceTable']['Races']:
    
        races['season'].append(int(item['season']))
        races['round'].append(int(item['round']))
        races['raceName'].append(item['raceName'])
        races['circuitId'].append(item['Circuit']['circuitId'])
        races['lat'].append(item['Circuit']['Location']['lat'])
        races['long'].append(item['Circuit']['Location']['long'])
        races['country'].append(item['Circuit']['Location']['country'])
        races['date'].append(item['date'])
        races['url'].append(item['url'])

# %%
# Usamos pd.DataFrame para convertirlo en DataFrame
pd.DataFrame(races)
# Out:
#      season  round                  raceName    circuitId       lat      long  \
# 0      2010      1        Bahrain Grand Prix      bahrain   26.0325   50.5106
# 1      2010      2     Australian Grand Prix  albert_park  -37.8497   144.968
# 2      2010      3      Malaysian Grand Prix       sepang   2.76083   101.738
# 3      2010      4        Chinese Grand Prix     shanghai   31.3389    121.22
# 4      2010      5        Spanish Grand Prix    catalunya     41.57   2.26111
# ..      ...    ...                       ...          ...       ...       ...
# 254    2022     18       Japanese Grand Prix       suzuka   34.8431   136.541
# 255    2022     19  United States Grand Prix     americas   30.1328  -97.6411
# 256    2022     20    Mexico City Grand Prix    rodriguez   19.4042  -99.0907
# 257    2022     21      Brazilian Grand Prix   interlagos  -23.7036  -46.6997
# 258    2022     22      Abu Dhabi Grand Prix   yas_marina   24.4672   54.6031
#
# ...

# %% [markdown]
# ## Tabla de Season

# %%
content['MRData']['SeasonTable']['Seasons']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2568\1735969586.py in <module>
# ----> 1 content['MRData']['SeasonTable']['Seasons']
#
# KeyError: 'SeasonTable'

# %%
url ='https://ergast.com/api/f1/seasons.json'
response = requests.get(url.format(2022))
content = json.loads(response.content)
content['MRData']['SeasonTable']['Seasons']
# Out:
# [{'season': '1950',
#   'url': 'http://en.wikipedia.org/wiki/1950_Formula_One_season'},
#  {'season': '1951',
#   'url': 'http://en.wikipedia.org/wiki/1951_Formula_One_season'},
#  {'season': '1952',
#   'url': 'http://en.wikipedia.org/wiki/1952_Formula_One_season'},
#  {'season': '1953',
#   'url': 'http://en.wikipedia.org/wiki/1953_Formula_One_season'},
#  {'season': '1954',
#   'url': 'http://en.wikipedia.org/wiki/1954_Formula_One_season'},
#  {'season': '1955',
#   'url': 'http://en.wikipedia.org/wiki/1955_Formula_One_season'},
#  {'season': '1956',
#   'url': 'http://en.wikipedia.org/wiki/1956_Formula_One_season'},
#  {'season': '1957',
#   'url': 'http://en.wikipedia.org/wiki/1957_Formula_One_season'},
#  {'season': '1958',
#   'url': 'http://en.wikipedia.org/wiki/1958_Formula_One_season'},
#  {'season': '1959',
#   'url': 'http://en.wikipedia.org/wiki/1959_Formula_One_season'},
#  {'season': '1960',
#   'url': 'http://en.wikipedia.org/wiki/1960_Formula_One_season'},
# ...

# %%
seasons = {'season': [],
        'url': []}
for item in content['MRData']['SeasonTable']['Seasons']:
    
        seasons['season'].append(int(item['season']))
        seasons['url'].append(item['url'])
        
pd.DataFrame(seasons)
# Out:
#     season                                                url
# 0     1950  http://en.wikipedia.org/wiki/1950_Formula_One_...
# 1     1951  http://en.wikipedia.org/wiki/1951_Formula_One_...
# 2     1952  http://en.wikipedia.org/wiki/1952_Formula_One_...
# 3     1953  http://en.wikipedia.org/wiki/1953_Formula_One_...
# 4     1954  http://en.wikipedia.org/wiki/1954_Formula_One_...
# 5     1955  http://en.wikipedia.org/wiki/1955_Formula_One_...
# 6     1956  http://en.wikipedia.org/wiki/1956_Formula_One_...
# 7     1957  http://en.wikipedia.org/wiki/1957_Formula_One_...
# 8     1958  http://en.wikipedia.org/wiki/1958_Formula_One_...
# 9     1959  http://en.wikipedia.org/wiki/1959_Formula_One_...
# 10    1960  http://en.wikipedia.org/wiki/1960_Formula_One_...
# 11    1961  http://en.wikipedia.org/wiki/1961_Formula_One_...
# 12    1962  http://en.wikipedia.org/wiki/1962_Formula_One_...
# 13    1963  http://en.wikipedia.org/wiki/1963_Formula_One_...
# ...

# %%
# Out:
#    season                                                url
# 0    1950  http://en.wikipedia.org/wiki/1950_Formula_One_...
# 1    1951  http://en.wikipedia.org/wiki/1951_Formula_One_...
# 2    1952  http://en.wikipedia.org/wiki/1952_Formula_One_...
# 3    1953  http://en.wikipedia.org/wiki/1953_Formula_One_...
# 4    1954  http://en.wikipedia.org/wiki/1954_Formula_One_...
# ..    ...                                                ...
# 85   1975  http://en.wikipedia.org/wiki/1975_Formula_One_...
# 86   1976  http://en.wikipedia.org/wiki/1976_Formula_One_...
# 87   1977  http://en.wikipedia.org/wiki/1977_Formula_One_...
# 88   1978  http://en.wikipedia.org/wiki/1978_Formula_One_...
# 89   1979  http://en.wikipedia.org/wiki/1979_Formula_One_...
#
# [90 rows x 2 columns]
