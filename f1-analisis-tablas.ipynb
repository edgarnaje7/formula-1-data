# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ## Tabla de Races

# %%
races = {'season': [],
        'round': [],
        'raceName': [],
        'circuitId': [],
        'lat': [],
        'long': [],
        'country': [],
        'date': [],
        'url': [],}

for i in list(range(2010,2023)):
    url ='https://ergast.com/api/f1/{}.json'
    response = requests.get(url.format(i))
    content = json.loads(response.content)
    
    for item in content['MRData']['RaceTable']['Races']:
    
        races['season'].append(int(item['season']))
        races['round'].append(int(item['round']))
        races['raceName'].append(item['raceName'])
        races['circuitId'].append(item['Circuit']['circuitId'])
        races['lat'].append(item['Circuit']['Location']['lat'])
        races['long'].append(item['Circuit']['Location']['long'])
        races['country'].append(item['Circuit']['Location']['country'])
        races['date'].append(item['date'])
        races['url'].append(item['url'])


#Creamos el DataFrame de races
pd.DataFrame(races)
# Out:
#    season  round               raceName    circuitId       lat     long  \
# 0    2010      1     Bahrain Grand Prix      bahrain   26.0325  50.5106
# 1    2010      2  Australian Grand Prix  albert_park  -37.8497  144.968
# 2    2010      3   Malaysian Grand Prix       sepang   2.76083  101.738
# 3    2010      4     Chinese Grand Prix     shanghai   31.3389   121.22
# 4    2010      5     Spanish Grand Prix    catalunya     41.57  2.26111
#
#      country        date                                                url
# 0    Bahrain  2010-03-14  http://en.wikipedia.org/wiki/2010_Bahrain_Gran...
# 1  Australia  2010-03-28  http://en.wikipedia.org/wiki/2010_Australian_G...
# 2   Malaysia  2010-04-04  http://en.wikipedia.org/wiki/2010_Malaysian_Gr...
# 3      China  2010-04-18  http://en.wikipedia.org/wiki/2010_Chinese_Gran...
# 4      Spain  2010-05-09  http://en.wikipedia.org/wiki/2010_Spanish_Gran...

# %%
pd.DataFrame(races).to_csv('races.csv', index = False)

# %% [markdown]
# ## Tabla de Seasons

# %%
url ='https://ergast.com/api/f1/seasons.json'
response = requests.get(url.format(2022))
content = json.loads(response.content)

seasons = {'season': [],
        'url': []}
  
for item in content['MRData']['SeasonTable']['Seasons']:
    
        seasons['season'].append(int(item['season']))
        seasons['url'].append(item['url'])

        
pd.DataFrame(seasons)
# Out:
#     season                                                url
# 0     1950  http://en.wikipedia.org/wiki/1950_Formula_One_...
# 1     1951  http://en.wikipedia.org/wiki/1951_Formula_One_...
# 2     1952  http://en.wikipedia.org/wiki/1952_Formula_One_...
# 3     1953  http://en.wikipedia.org/wiki/1953_Formula_One_...
# 4     1954  http://en.wikipedia.org/wiki/1954_Formula_One_...
# 5     1955  http://en.wikipedia.org/wiki/1955_Formula_One_...
# 6     1956  http://en.wikipedia.org/wiki/1956_Formula_One_...
# 7     1957  http://en.wikipedia.org/wiki/1957_Formula_One_...
# 8     1958  http://en.wikipedia.org/wiki/1958_Formula_One_...
# 9     1959  http://en.wikipedia.org/wiki/1959_Formula_One_...
# 10    1960  http://en.wikipedia.org/wiki/1960_Formula_One_...
# 11    1961  http://en.wikipedia.org/wiki/1961_Formula_One_...
# 12    1962  http://en.wikipedia.org/wiki/1962_Formula_One_...
# 13    1963  http://en.wikipedia.org/wiki/1963_Formula_One_...
# 14    1964  http://en.wikipedia.org/wiki/1964_Formula_One_...
# 15    1965  http://en.wikipedia.org/wiki/1965_Formula_One_...
# 16    1966  http://en.wikipedia.org/wiki/1966_Formula_One_...
# 17    1967  http://en.wikipedia.org/wiki/1967_Formula_One_...
# 18    1968  http://en.wikipedia.org/wiki/1968_Formula_One_...
# 19    1969  http://en.wikipedia.org/wiki/1969_Formula_One_...
# 20    1970  http://en.wikipedia.org/wiki/1970_Formula_One_...
# 21    1971  http://en.wikipedia.org/wiki/1971_Formula_One_...
# 22    1972  http://en.wikipedia.org/wiki/1972_Formula_One_...
# 23    1973  http://en.wikipedia.org/wiki/1973_Formula_One_...
# 24    1974  http://en.wikipedia.org/wiki/1974_Formula_One_...
# 25    1975  http://en.wikipedia.org/wiki/1975_Formula_One_...
# 26    1976  http://en.wikipedia.org/wiki/1976_Formula_One_...
# 27    1977  http://en.wikipedia.org/wiki/1977_Formula_One_...
# 28    1978  http://en.wikipedia.org/wiki/1978_Formula_One_...
# 29    1979  http://en.wikipedia.org/wiki/1979_Formula_One_...

# %%
pd.DataFrame(seasons).to_csv('seasons.csv', index = False)

# %% [markdown]
# ## Tabla de Drivers

# %%
drivers = {'driverId': [],
           'givenName': [],
           'familyName': [],
           'dateOfBirth': [],
           'nationality': [],
           'url': []}

for i in list(range(2010,2023)):
    url ='https://ergast.com/api/f1/{}/drivers.json'
    response = requests.get(url.format(i))
    content = json.loads(response.content)
    
    for item in content['MRData']['DriverTable']['Drivers']:
    
        drivers['driverId'].append(item['driverId'])
        drivers['givenName'].append(item['givenName'])
        drivers['familyName'].append(item['familyName'])
        drivers['dateOfBirth'].append(item['dateOfBirth'])
        drivers['nationality'].append(item['nationality'])
        drivers['url'].append(item['url'])

        
pd.DataFrame(drivers)
# Out:
#            driverId  givenName   familyName dateOfBirth nationality  \
# 0       alguersuari      Jaime  Alguersuari  1990-03-23     Spanish
# 1            alonso   Fernando       Alonso  1981-07-29     Spanish
# 2       barrichello     Rubens  Barrichello  1972-05-23   Brazilian
# 3             buemi  Sébastien        Buemi  1988-10-31       Swiss
# 4            button     Jenson       Button  1980-01-19     British
# ..              ...        ...          ...         ...         ...
# 299          stroll      Lance       Stroll  1998-10-29    Canadian
# 300         tsunoda       Yuki      Tsunoda  2000-05-11    Japanese
# 301  max_verstappen        Max   Verstappen  1997-09-30       Dutch
# 302          vettel  Sebastian       Vettel  1987-07-03      German
# 303            zhou     Guanyu         Zhou  1999-05-30     Chinese
#
#                                                    url
# 0       http://en.wikipedia.org/wiki/Jaime_Alguersuari
# 1         http://en.wikipedia.org/wiki/Fernando_Alonso
# 2      http://en.wikipedia.org/wiki/Rubens_Barrichello
# 3    http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi
# 4           http://en.wikipedia.org/wiki/Jenson_Button
# ..                                                 ...
# 299          http://en.wikipedia.org/wiki/Lance_Stroll
# 300          http://en.wikipedia.org/wiki/Yuki_Tsunoda
# 301        http://en.wikipedia.org/wiki/Max_Verstappen
# 302      http://en.wikipedia.org/wiki/Sebastian_Vettel
# 303           http://en.wikipedia.org/wiki/Guanyu_Zhou
#
# [304 rows x 6 columns]

# %%
pd.DataFrame(drivers).to_csv('drivers.csv', index = False)

# %% [markdown]
# ## Tabla de Constructors

# %%
Constructors = {'constructorId': [],
                'name': [],
                'nationality': [],
                'url': []}



for i in list(range(2010,2023)):
    url ='https://ergast.com/api/f1/{}/constructors.json'
    response = requests.get(url.format(i))
    content = json.loads(response.content)
    
    for item in content['MRData']['ConstructorTable']['Constructors']:
    
        Constructors['constructorId'].append(item['constructorId'])
        Constructors['name'].append(item['name'])
        Constructors['nationality'].append(item['nationality'])
        Constructors['url'].append(item['url'])


        
pd.DataFrame(Constructors)
# Out:
#     constructorId          name nationality  \
# 0         ferrari       Ferrari     Italian
# 1     force_india   Force India      Indian
# 2             hrt           HRT     Spanish
# 3    lotus_racing         Lotus   Malaysian
# 4         mclaren       McLaren     British
# ..            ...           ...         ...
# 134          haas  Haas F1 Team    American
# 135       mclaren       McLaren     British
# 136      mercedes      Mercedes      German
# 137      red_bull      Red Bull    Austrian
# 138      williams      Williams     British
#
#                                                    url
# 0        http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 1    http://en.wikipedia.org/wiki/Racing_Point_Forc...
# 2         http://en.wikipedia.org/wiki/Hispania_Racing
# 3            http://en.wikipedia.org/wiki/Lotus_Racing
# 4                 http://en.wikipedia.org/wiki/McLaren
# ..                                                 ...
# 134          http://en.wikipedia.org/wiki/Haas_F1_Team
# 135               http://en.wikipedia.org/wiki/McLaren
# 136  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 137       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 138  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
#
# [139 rows x 4 columns]

# %%
pd.DataFrame(Constructors).to_csv('Constructors.csv', index = False)

# %% [markdown]
# ## Tabla de Circuits

# %%
Circuits = {'circuitId': [],
            'circuitName': [],
            'lat': [],
            'long': [],
            'locality': [],
            'country': [],
            'url': []}


for i in list(range(2010,2023)):
    url ='https://ergast.com/api/f1/{}/circuits.json'
    response = requests.get(url.format(i))
    content = json.loads(response.content)
    
    for item in content['MRData']['CircuitTable']['Circuits']:
    
        Circuits['circuitId'].append(item['circuitId'])
        Circuits['circuitName'].append(item['circuitName'])
        Circuits['lat'].append(item['Location']['lat'])
        Circuits['long'].append(item['Location']['long'])
        Circuits['locality'].append(item['Location']['locality'])
        Circuits['country'].append(item['Location']['country'])
        Circuits['url'].append(item['url'])


pd.DataFrame(Circuits)
# Out:
#           circuitId                     circuitName       lat      long  \
# 0       albert_park  Albert Park Grand Prix Circuit  -37.8497   144.968
# 1           bahrain   Bahrain International Circuit   26.0325   50.5106
# 2         catalunya  Circuit de Barcelona-Catalunya     41.57   2.26111
# 3    hockenheimring                  Hockenheimring   49.3278   8.56583
# 4       hungaroring                     Hungaroring   47.5789   19.2486
# ..              ...                             ...       ...       ...
# 250             spa    Circuit de Spa-Francorchamps   50.4372   5.97139
# 251          suzuka                  Suzuka Circuit   34.8431   136.541
# 252      villeneuve       Circuit Gilles Villeneuve      45.5  -73.5228
# 253      yas_marina              Yas Marina Circuit   24.4672   54.6031
# 254       zandvoort          Circuit Park Zandvoort   52.3888   4.54092
#
#        locality      country  \
# 0     Melbourne    Australia
# 1        Sakhir      Bahrain
# 2      Montmeló        Spain
# 3    Hockenheim      Germany
# 4      Budapest      Hungary
# ..          ...          ...
# 250         Spa      Belgium
# 251      Suzuka        Japan
# 252    Montreal       Canada
# 253   Abu Dhabi          UAE
# 254   Zandvoort  Netherlands
#
#                                                    url
# 0    http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1    http://en.wikipedia.org/wiki/Bahrain_Internati...
# 2    http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 3          http://en.wikipedia.org/wiki/Hockenheimring
# 4             http://en.wikipedia.org/wiki/Hungaroring
# ..                                                 ...
# 250  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 251        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 252  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 253    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 254     http://en.wikipedia.org/wiki/Circuit_Zandvoort
#
# [255 rows x 7 columns]

# %%
pd.DataFrame(Circuits).to_csv('Circuits.csv', index = False)

# %% [markdown]
# ## Tabla de Qualifying

# %%
url ='http://ergast.com/api/f1/2022/qualifying.json'
response = requests.get(url)
content = json.loads(response.content)

# %%
content['MRData']['RaceTable'].keys()
# Out:
# dict_keys(['season', 'Races'])

# %%
content['MRData']['RaceTable']['Races'][0]
# Out:
# {'season': '2022',
#  'round': '1',
#  'url': 'http://en.wikipedia.org/wiki/2022_Bahrain_Grand_Prix',
#  'raceName': 'Bahrain Grand Prix',
#  'Circuit': {'circuitId': 'bahrain',
#   'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#   'circuitName': 'Bahrain International Circuit',
#   'Location': {'lat': '26.0325',
#    'long': '50.5106',
#    'locality': 'Sakhir',
#    'country': 'Bahrain'}},
#  'date': '2022-03-20',
#  'time': '15:00:00Z',
#  'QualifyingResults': [{'number': '16',
#    'position': '1',
#    'Driver': {'driverId': 'leclerc',
#     'permanentNumber': '16',
#     'code': 'LEC',
#     'url': 'http://en.wikipedia.org/wiki/Charles_Leclerc',
#     'givenName': 'Charles',
#     'familyName': 'Leclerc',
#     'dateOfBirth': '1997-10-16',
#     'nationality': 'Monegasque'},
#    'Constructor': {'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'},
#    'Q1': '1:31.471',
#    'Q2': '1:30.932',
#    'Q3': '1:30.558'},
#   {'number': '1',
#    'position': '2',
#    'Driver': {'driverId': 'max_verstappen',
#     'permanentNumber': '33',
#     'code': 'VER',
#     'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#     'givenName': 'Max',
#     'familyName': 'Verstappen',
#     'dateOfBirth': '1997-09-30',
#     'nationality': 'Dutch'},
#    'Constructor': {'constructorId': 'red_bull',
#     'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#     'name': 'Red Bull',
#     'nationality': 'Austrian'},
#    'Q1': '1:31.785',
#    'Q2': '1:30.757',
#    'Q3': '1:30.681'},
#   {'number': '55',
#    'position': '3',
#    'Driver': {'driverId': 'sainz',
#     'permanentNumber': '55',
#     'code': 'SAI',
#     'url': 'http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.',
#     'givenName': 'Carlos',
#     'familyName': 'Sainz',
#     'dateOfBirth': '1994-09-01',
#     'nationality': 'Spanish'},
#    'Constructor': {'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'},
#    'Q1': '1:31.567',
#    'Q2': '1:30.787',
#    'Q3': '1:30.687'},
#   {'number': '11',
#    'position': '4',
#    'Driver': {'driverId': 'perez',
#     'permanentNumber': '11',
#     'code': 'PER',
#     'url': 'http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez',
#     'givenName': 'Sergio',
#     'familyName': 'Pérez',
#     'dateOfBirth': '1990-01-26',
#     'nationality': 'Mexican'},
#    'Constructor': {'constructorId': 'red_bull',
#     'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#     'name': 'Red Bull',
#     'nationality': 'Austrian'},
#    'Q1': '1:32.311',
#    'Q2': '1:31.008',
#    'Q3': '1:30.921'},
#   {'number': '44',
#    'position': '5',
#    'Driver': {'driverId': 'hamilton',
#     'permanentNumber': '44',
#     'code': 'HAM',
#     'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#     'givenName': 'Lewis',
#     'familyName': 'Hamilton',
#     'dateOfBirth': '1985-01-07',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'mercedes',
#     'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#     'name': 'Mercedes',
#     'nationality': 'German'},
#    'Q1': '1:32.285',
#    'Q2': '1:31.048',
#    'Q3': '1:31.238'},
#   {'number': '77',
#    'position': '6',
#    'Driver': {'driverId': 'bottas',
#     'permanentNumber': '77',
#     'code': 'BOT',
#     'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#     'givenName': 'Valtteri',
#     'familyName': 'Bottas',
#     'dateOfBirth': '1989-08-28',
#     'nationality': 'Finnish'},
#    'Constructor': {'constructorId': 'alfa',
#     'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#     'name': 'Alfa Romeo',
#     'nationality': 'Swiss'},
#    'Q1': '1:31.919',
#    'Q2': '1:31.717',
#    'Q3': '1:31.560'},
#   {'number': '20',
#    'position': '7',
#    'Driver': {'driverId': 'kevin_magnussen',
#     'permanentNumber': '20',
#     'code': 'MAG',
#     'url': 'http://en.wikipedia.org/wiki/Kevin_Magnussen',
#     'givenName': 'Kevin',
#     'familyName': 'Magnussen',
#     'dateOfBirth': '1992-10-05',
#     'nationality': 'Danish'},
#    'Constructor': {'constructorId': 'haas',
#     'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#     'name': 'Haas F1 Team',
#     'nationality': 'American'},
#    'Q1': '1:31.955',
#    'Q2': '1:31.461',
#    'Q3': '1:31.808'},
#   {'number': '14',
#    'position': '8',
#    'Driver': {'driverId': 'alonso',
#     'permanentNumber': '14',
#     'code': 'ALO',
#     'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#     'givenName': 'Fernando',
#     'familyName': 'Alonso',
#     'dateOfBirth': '1981-07-29',
#     'nationality': 'Spanish'},
#    'Constructor': {'constructorId': 'alpine',
#     'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#     'name': 'Alpine F1 Team',
#     'nationality': 'French'},
#    'Q1': '1:32.346',
#    'Q2': '1:31.621',
#    'Q3': '1:32.195'},
#   {'number': '63',
#    'position': '9',
#    'Driver': {'driverId': 'russell',
#     'permanentNumber': '63',
#     'code': 'RUS',
#     'url': 'http://en.wikipedia.org/wiki/George_Russell_%28racing_driver%29',
#     'givenName': 'George',
#     'familyName': 'Russell',
#     'dateOfBirth': '1998-02-15',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'mercedes',
#     'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#     'name': 'Mercedes',
#     'nationality': 'German'},
#    'Q1': '1:32.269',
#    'Q2': '1:31.252',
#    'Q3': '1:32.216'},
#   {'number': '10',
#    'position': '10',
#    'Driver': {'driverId': 'gasly',
#     'permanentNumber': '10',
#     'code': 'GAS',
#     'url': 'http://en.wikipedia.org/wiki/Pierre_Gasly',
#     'givenName': 'Pierre',
#     'familyName': 'Gasly',
#     'dateOfBirth': '1996-02-07',
#     'nationality': 'French'},
#    'Constructor': {'constructorId': 'alphatauri',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#     'name': 'AlphaTauri',
#     'nationality': 'Italian'},
#    'Q1': '1:32.096',
#    'Q2': '1:31.635',
#    'Q3': '1:32.338'},
#   {'number': '31',
#    'position': '11',
#    'Driver': {'driverId': 'ocon',
#     'permanentNumber': '31',
#     'code': 'OCO',
#     'url': 'http://en.wikipedia.org/wiki/Esteban_Ocon',
#     'givenName': 'Esteban',
#     'familyName': 'Ocon',
#     'dateOfBirth': '1996-09-17',
#     'nationality': 'French'},
#    'Constructor': {'constructorId': 'alpine',
#     'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#     'name': 'Alpine F1 Team',
#     'nationality': 'French'},
#    'Q1': '1:32.041',
#    'Q2': '1:31.782'},
#   {'number': '47',
#    'position': '12',
#    'Driver': {'driverId': 'mick_schumacher',
#     'permanentNumber': '47',
#     'code': 'MSC',
#     'url': 'http://en.wikipedia.org/wiki/Mick_Schumacher',
#     'givenName': 'Mick',
#     'familyName': 'Schumacher',
#     'dateOfBirth': '1999-03-22',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'haas',
#     'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#     'name': 'Haas F1 Team',
#     'nationality': 'American'},
#    'Q1': '1:32.380',
#    'Q2': '1:31.998'},
#   {'number': '4',
#    'position': '13',
#    'Driver': {'driverId': 'norris',
#     'permanentNumber': '4',
#     'code': 'NOR',
#     'url': 'http://en.wikipedia.org/wiki/Lando_Norris',
#     'givenName': 'Lando',
#     'familyName': 'Norris',
#     'dateOfBirth': '1999-11-13',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
#     'nationality': 'British'},
#    'Q1': '1:32.239',
#    'Q2': '1:32.008'},
#   {'number': '23',
#    'position': '14',
#    'Driver': {'driverId': 'albon',
#     'permanentNumber': '23',
#     'code': 'ALB',
#     'url': 'http://en.wikipedia.org/wiki/Alexander_Albon',
#     'givenName': 'Alexander',
#     'familyName': 'Albon',
#     'dateOfBirth': '1996-03-23',
#     'nationality': 'Thai'},
#    'Constructor': {'constructorId': 'williams',
#     'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#     'name': 'Williams',
#     'nationality': 'British'},
#    'Q1': '1:32.726',
#    'Q2': '1:32.664'},
#   {'number': '24',
#    'position': '15',
#    'Driver': {'driverId': 'zhou',
#     'permanentNumber': '24',
#     'code': 'ZHO',
#     'url': 'http://en.wikipedia.org/wiki/Guanyu_Zhou',
#     'givenName': 'Guanyu',
#     'familyName': 'Zhou',
#     'dateOfBirth': '1999-05-30',
#     'nationality': 'Chinese'},
#    'Constructor': {'constructorId': 'alfa',
#     'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#     'name': 'Alfa Romeo',
#     'nationality': 'Swiss'},
#    'Q1': '1:32.493',
#    'Q2': '1:33.543'},
#   {'number': '22',
#    'position': '16',
#    'Driver': {'driverId': 'tsunoda',
#     'permanentNumber': '22',
#     'code': 'TSU',
#     'url': 'http://en.wikipedia.org/wiki/Yuki_Tsunoda',
#     'givenName': 'Yuki',
#     'familyName': 'Tsunoda',
#     'dateOfBirth': '2000-05-11',
#     'nationality': 'Japanese'},
#    'Constructor': {'constructorId': 'alphatauri',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#     'name': 'AlphaTauri',
#     'nationality': 'Italian'},
#    'Q1': '1:32.750'},
#   {'number': '27',
#    'position': '17',
#    'Driver': {'driverId': 'hulkenberg',
#     'permanentNumber': '27',
#     'code': 'HUL',
#     'url': 'http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg',
#     'givenName': 'Nico',
#     'familyName': 'Hülkenberg',
#     'dateOfBirth': '1987-08-19',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'aston_martin',
#     'url': 'http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#     'name': 'Aston Martin',
#     'nationality': 'British'},
#    'Q1': '1:32.777'},
#   {'number': '3',
#    'position': '18',
#    'Driver': {'driverId': 'ricciardo',
#     'permanentNumber': '3',
#     'code': 'RIC',
#     'url': 'http://en.wikipedia.org/wiki/Daniel_Ricciardo',
#     'givenName': 'Daniel',
#     'familyName': 'Ricciardo',
#     'dateOfBirth': '1989-07-01',
#     'nationality': 'Australian'},
#    'Constructor': {'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
#     'nationality': 'British'},
#    'Q1': '1:32.945'},
#   {'number': '18',
#    'position': '19',
#    'Driver': {'driverId': 'stroll',
#     'permanentNumber': '18',
#     'code': 'STR',
#     'url': 'http://en.wikipedia.org/wiki/Lance_Stroll',
#     'givenName': 'Lance',
#     'familyName': 'Stroll',
#     'dateOfBirth': '1998-10-29',
#     'nationality': 'Canadian'},
#    'Constructor': {'constructorId': 'aston_martin',
#     'url': 'http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#     'name': 'Aston Martin',
#     'nationality': 'British'},
#    'Q1': '1:33.032'},
#   {'number': '6',
#    'position': '20',
#    'Driver': {'driverId': 'latifi',
#     'permanentNumber': '6',
#     'code': 'LAT',
#     'url': 'http://en.wikipedia.org/wiki/Nicholas_Latifi',
#     'givenName': 'Nicholas',
#     'familyName': 'Latifi',
#     'dateOfBirth': '1995-06-29',
#     'nationality': 'Canadian'},
#    'Constructor': {'constructorId': 'williams',
#     'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#     'name': 'Williams',
#     'nationality': 'British'},
#    'Q1': '1:33.634'}]}

# %%
content['MRData']['RaceTable']['Races']['QualifyingResults']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9796\3797007333.py in <module>
# ----> 1 content['MRData']['RaceTable']['Races']['QualifyingResults']
#
# TypeError: list indices must be integers or slices, not str

# %%
Qualifying = {'circuitId': [],
              'number': [],
              'position': [],
              'driverId': [],
              'constructorId': [],
              'Q1': [],
              'Q2': [],
              'Q3': []}

url ='http://ergast.com/api/f1/2022.json'
response = requests.get(url)
content = json.loads(response.content)

for item in content['MRData']['RaceTable']['Races']:
    
        Qualifying['circuitId'].append(item['Circuit']['circuitId'])
        Qualifying['number'].append(item['QualifyingResults'])
        

        
Qualifying
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9796\1422295490.py in <module>
#      15
#      16         Qualifying['circuitId'].append(item['Circuit']['circuitId'])
# ---> 17         Qualifying['number'].append(item['QualifyingResults'])
#      18
#      19
#
# KeyError: 'QualifyingResults'

# %%
Qualifying = {'circuitId': [],
              'number': [],
              'position': [],
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5412\1511898475.py in <module>
#      15
#      16         Qualifying['circuitId'].append(item['Circuit']['circuitId'])
# ---> 17         Qualifying['number'].append(item['QualifyingResults']['number'])
#      18
#      19
#
# KeyError: 'QualifyingResults'

# %%
Qualifying={"year":[],
            "driverId":[],
            "ConstructorId":[],
            "number":[],
            "position":[],
            "qualifyId":[],
            "raceId":[],
            "q1":[],
            "q2":[],
            "q3":[]}
       
       

for year in range(2010,2023):
    url='http://ergast.com/api/f1' 
    url1=url+'/{}.json?limit=1000'
    url2=url+'/{}'.format(year)
    response = requests.get(url1.format(year)) 
    content=json.loads(response.content)
    link=[]
    
    for k in range(1,len(content['MRData']['RaceTable']['Races'])+1):
        url3=url2+'/{}/qualifying.json?limit=100'
        link.append(url3.format(k))
        
    for lk in link:
        response = requests.get(lk)
        content=json.loads(response.content)
        
        for it in content['MRData']['RaceTable']['Races']:
            
            for it1 in content['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
                Qualifying["year"].append(int(it['season']))
                Qualifying["qualifyId"].append(int( it['round']))
                Qualifying["raceId"].append(it['raceName']) 
                Qualifying["driverId"].append(it1['Driver']['driverId'])   
                Qualifying["ConstructorId"].append(it1['Constructor']['constructorId'])
                Qualifying["number"].append(int(it1['number']))
                Qualifying["position"].append(int(it1['position']))
                Qualifying["q1"].append(it1['Q1'])
                try:
                    quali["q2"].append(it1['Q2'])
                except:
                    quali["q2"].append("")
                try:
                    quali["q3"].append(it1['Q3'])
                except:
                    quali["q3"].append("")

dfquali=pd.DataFrame.from_dict(Qualifying,orient='index')
Qualifying=dfquali.transpose()
Qualifying
# Out:
#       year         driverId ConstructorId number position qualifyId  \
# 0     2010           vettel      red_bull      5        1         1
# 1     2010            massa       ferrari      7        2         1
# 2     2010           alonso       ferrari      8        3         1
# 3     2010         hamilton       mclaren      2        4         1
# 4     2010          rosberg      mercedes      4        5         1
# ...    ...              ...           ...    ...      ...       ...
# 5488  2022  kevin_magnussen          haas     20       16        22
# 5489  2022            gasly    alphatauri     10       17        22
# 5490  2022           bottas          alfa     77       18        22
# 5491  2022            albon      williams     23       19        22
# 5492  2022           latifi      williams      6       20        22
#
#                     raceId        q1    q2    q3
# 0       Bahrain Grand Prix  1:55.029  None  None
# 1       Bahrain Grand Prix  1:55.313  None  None
# 2       Bahrain Grand Prix  1:54.612  None  None
# 3       Bahrain Grand Prix  1:55.341  None  None
# 4       Bahrain Grand Prix  1:55.463  None  None
# ...                    ...       ...   ...   ...
# 5488  Abu Dhabi Grand Prix  1:25.834  None  None
# 5489  Abu Dhabi Grand Prix  1:25.859  None  None
# 5490  Abu Dhabi Grand Prix  1:25.892  None  None
# 5491  Abu Dhabi Grand Prix  1:26.028  None  None
# 5492  Abu Dhabi Grand Prix  1:26.054  None  None
#
# [5493 rows x 10 columns]

# %%
Qualifying.to_csv('Qualifying.csv',index=False)
